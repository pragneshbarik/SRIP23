# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Subject: Pragnesh
df = pd.read_csv('WIPAD71.csv')
df.set_index("currTime", inplace=True)
df.plot(kind='line', subplots=True, figsize=(30, 20))

# %%
df.plot(kind='line', subplots=True, figsize=(30, 20))
# Out:
# array([<AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>], dtype=object)

# %%
df.sum()
# Out:
# th_cap    10893.18
# gyroZ     10993.17
# indHS        44.00
# indLP        44.00
# indMS        43.00
# indTO        43.00
# indZC        12.00
# dtype: float64

# %%
# Subject: Ronak Vyas
df = pd.read_csv('WIPAD73.csv')
df.set_index("currTime", inplace=True)

# %%
df.plot(kind="line", subplots=True, figsize=(30, 20))
# Out:
# array([<AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>], dtype=object)

# %%
df.sum()
# Out:
# th_cap    35083.75
# gyroZ     35518.65
# indHS        97.00
# indLP        88.00
# indMS        97.00
# indTO        67.00
# indZC        61.00
# dtype: float64

# %%
# Subject: Jenish Desai
df = pd.read_csv('WIPAD83.csv')
df.set_index("currTime", inplace=True)
df.plot(kind='line', subplots=True, figsize=(30, 20))
# Out:
# array([<AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>], dtype=object)

# %%
df.sum()
# Out:
# th_cap    50070.72
# gyroZ     51156.56
# indHS       156.00
# indLP       122.00
# indMS       155.00
# indTO        90.00
# indZC        78.00
# dtype: float64

# %%
# Subject: Dhruv Detroja
df = pd.read_csv('WIPAD87.csv')
df.set_index("currTime", inplace=True)
df.plot(kind='line', subplots=True, figsize=(30, 20))
# Out:
# array([<AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>, <AxesSubplot:xlabel='currTime'>,
#        <AxesSubplot:xlabel='currTime'>], dtype=object)

# %%
df.sum()
# Out:
# th_cap    37525.60
# gyroZ     42664.69
# indHS       157.00
# indLP       147.00
# indMS       156.00
# indTO       131.00
# indZC       129.00
# dtype: float64
